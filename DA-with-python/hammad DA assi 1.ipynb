# %%
name = "Hammad Ali Malik"
father_name = "Ahmed ALI"
dob = "18-07-2002"

print("Name:\t", name)
print("Father Name:\t", father_name)
print("Date of Birth:\n", dob)
# Out:
# Name:	 Hammad Ali Malik
# Father Name:	 Ahmed ALI
# Date of Birth:
#  18-07-2002

# %%
name = "Hammad Ali Malik"
age = 24
city = "Karachi"
field = "Software Engineering Student"

bio = f"My name is {name}. I am {age} years old and from {city}. I am a {field}."
print(bio)
# Out:
# My name is Hammad Ali Malik. I am 24 years old and from Karachi. I am a Software Engineering Student.

# %%
a = 10
b = 3

print(a + b)  # add
print(a - b)  # subtract  
print(a * b)  # multiply
print(a / b)  # divide
print(a > b)  # check if a is greater
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# True

# %%
english = 80
islamiat = 90
maths = 85

total = english + islamiat + maths
percentage = total / 300 * 100

print("Total Marks:", total)
print("Percentage:", percentage)
# Out:
# Total Marks: 255
# Percentage: 85.0

# %%
a = 5
b = 10

print("Before:", a, b)

temp = a
a = b
b = temp

print("After:", a, b)
# Out:
# Before: 5 10
# After: 10 5

# %%
pi = 3.14
radius = 5

area = pi * radius * radius
circumference = 2 * pi * radius

print("Area:", area)
print("Circumference:", circumference)
# Out:
# Area: 78.5
# Circumference: 31.400000000000002

# %%
price = 1000
discount = 20

discount_amount = price * discount / 100
final_price = price - discount_amount

print("Discount:", discount_amount)
print("Final Price:", final_price)
# Out:
# Discount: 200.0
# Final Price: 800.0
